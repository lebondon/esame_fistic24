# %% [markdown]
# # Luxury Watch
#
# **Column Details**
# * Brand: The brand of the watch.
# * Model: The model name or number of the watch.
# * Case Material: The material used to make the watch case (e.g., stainless steel, titanium, gold).
# * Strap Material: The material used to make the watch strap or bracelet (e.g., leather, rubber, metal).
# * Movement Type: The type of movement used in the watch (e.g., automatic, manual, quartz).
# * Water Resistance: The level of water resistance for the watch (e.g., 30 meters, 100 meters, 600 meters).
# * Case Diameter (mm): The diameter of the watch case in millimeters.
# * Case Thickness (mm): The thickness of the watch case in millimeters.
# * Band Width (mm): The width of the watch strap or bracelet in millimeters.
# * Dial Color: The color of the watch dial (e.g., black, blue, silver).
# * Crystal Material: The material used for the watch crystal (e.g., sapphire, mineral, hardlex).
# * Complications: Any additional functions or features beyond timekeeping (e.g., date display, chronograph, GMT).
# * Power Reserve: The amount of time the watch can run without winding or wearing (e.g., 48 hours, 72 hours).
# * Price (USD): The retail price of the watch in US dollars.

# %%
path = "https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/Luxurywatch.csv"

# %%
import pandas as pd
df=pd.read_csv(path)
df
# Out:
#                    Brand              Model    Case Material   Strap Material  \
# 0                  Rolex         Submariner  Stainless Steel  Stainless Steel
# 1                  Omega          Seamaster         Titanium           Rubber
# 2              Tag Heuer            Carrera  Stainless Steel          Leather
# 3              Breitling          Navitimer  Stainless Steel  Stainless Steel
# 4                Cartier          Tank Solo  Stainless Steel          Leather
# ..                   ...                ...              ...              ...
# 502              Breguet          Classique    18k Rose Gold          Leather
# 503            Blancpain      Fifty Fathoms  Stainless Steel           Fabric
# 504             Longines  Master Collection  Stainless Steel          Leather
# 505  Vacheron Constantin           Overseas  Stainless Steel  Stainless Steel
# 506  Frederique Constant           Classics  Stainless Steel          Leather
#
# ...

# %%
df100=df.head(100)
df100.to_csv('LW_100.csv')

# %%
df.dtypes
# Out:
# Brand                   object
# Model                   object
# Case Material           object
# Strap Material          object
# Movement Type           object
# Water Resistance        object
# Case Diameter (mm)     float64
# Case Thickness (mm)    float64
# Band Width (mm)        float64
# Dial Color              object
# Crystal Material        object
# Complications           object
# Power Reserve           object
# Price (USD)             object
# dtype: object

# %%
df['Brand'].value_counts()
# Out:
# Brand
# IWC                    39
# Audemars Piguet        38
# Patek Philippe         33
# Zenith                 30
# Blancpain              29
# Rolex                  27
# Breguet                26
# Hublot                 26
# Vacheron Constantin    25
# Panerai                25
# Omega                  23
# Girard-Perregaux       20
# Cartier                19
# Breitling              16
# Jaeger-LeCoultre       16
# Chopard                14
# Tudor                  14
# Tag Heuer              11
# Longines               10
# Ulysse Nardin          10
# Montblanc               9
# Piaget                  6
# Seiko                   5
# Jaquet Droz             5
# Hamilton                4
# Bell & Ross             4
# Sinn                    3
# Bulgari                 3
# Citizen                 2
# Oris                    2
# Tissot                  2
# TAG Heuer               2
# A. Lange & Söhne        2
# Frederique Constant     2
# Glashütte Original      1
# ...

# %%
df['Crystal Material'].value_counts()
# Out:
# Crystal Material
# Sapphire    489
# Hesalite     13
# Hardlex       3
# Mineral       2
# Name: count, dtype: int64

# %%
df['Case Material'].value_counts()
# Out:
# Case Material
# Stainless Steel           404
# Titanium                   37
# Rose Gold                  12
# 18k Rose Gold              10
# Ceramic                     9
# White Gold                  9
# 18k White Gold              7
# 18K White Gold              5
# 18K Rose Gold               3
# Carbon Fiber                3
# 18K Yellow Gold             2
# German Submarine Steel      1
# High-Tech Ceramic           1
# Bronze                      1
# Yellow Gold                 1
# 18k King Gold               1
# 18k Yellow Gold             1
# Name: count, dtype: int64

# %%
df['Movement Type'].value_counts()
# Out:
# Movement Type
# Automatic    442
# Manual        51
# Quartz        12
# Eco-Drive      2
# Name: count, dtype: int64

# %%
df['Model'].value_counts()
# Out:
# Model
# Royal Oak             38
# Fifty Fathoms         29
# Nautilus              26
# Classique             24
# Portugieser           24
#                       ..
# Clifton Baumatic       1
# Pilot's Watch Mark     1
# Constellation          1
# Chronomat              1
# Polo                   1
# Name: count, Length: 95, dtype: int64

# %%
df['Strap Material'].value_counts()
# Out:
# Strap Material
# Leather             224
# Stainless Steel     166
# Rubber               74
# Fabric               11
# Canvas               10
# Silicone              5
# NATO Strap            4
# Jubilee Bracelet      3
# Jubilee               2
# Alligator             2
# Rose Gold             2
# Titanium              2
# Textile               1
# NATO strap            1
# Name: count, dtype: int64

# %%
df['Price (USD)'] = df['Price (USD)'].str.replace(',', '').astype(float)
df['Price (USD)']
# Out:
# 0       9500.0
# 1       5800.0
# 2       4200.0
# 3       7900.0
# 4       2800.0
#         ...
# 502    21500.0
# 503    13500.0
# 504     1800.0
# 505    19000.0
# 506     1200.0
# Name: Price (USD), Length: 507, dtype: float64

# %%
df['Water Resistance'] = df['Water Resistance'].str.extract('(\d+)').astype(float)
df['Water Resistance']
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_12041/2601459253.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['Water Resistance'] = df['Water Resistance'].str.extract('(\d+)').astype(float)
# 0      300.0
# 1      600.0
# 2      100.0
# 3       30.0
# 4       30.0
#        ...
# 502     30.0
# 503    300.0
# 504     30.0
# 505    150.0
# 506     50.0
# Name: Water Resistance, Length: 507, dtype: float64

# %%
df['Power Reserve'] = df['Power Reserve'].str.extract('(\d+)').astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_12041/4151156147.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['Power Reserve'] = df['Power Reserve'].str.extract('(\d+)').astype(float)

# %%
df
# Out:
#                    Brand              Model    Case Material   Strap Material  \
# 0                  Rolex         Submariner  Stainless Steel  Stainless Steel
# 1                  Omega          Seamaster         Titanium           Rubber
# 2              Tag Heuer            Carrera  Stainless Steel          Leather
# 3              Breitling          Navitimer  Stainless Steel  Stainless Steel
# 4                Cartier          Tank Solo  Stainless Steel          Leather
# ..                   ...                ...              ...              ...
# 502              Breguet          Classique    18k Rose Gold          Leather
# 503            Blancpain      Fifty Fathoms  Stainless Steel           Fabric
# 504             Longines  Master Collection  Stainless Steel          Leather
# 505  Vacheron Constantin           Overseas  Stainless Steel  Stainless Steel
# 506  Frederique Constant           Classics  Stainless Steel          Leather
#
# ...

# %%
df['f_stainless_steel'] = (df['Case Material'] == 'Stainless Steel').astype(int)
df['f_gold'] = df['Case Material'].str.contains('Gold', case=False).astype(int)
df['f_titanium'] = (df['Case Material'] == 'Titanium').astype(int)
df
# Out:
#                    Brand              Model    Case Material   Strap Material  \
# 0                  Rolex         Submariner  Stainless Steel  Stainless Steel
# 1                  Omega          Seamaster         Titanium           Rubber
# 2              Tag Heuer            Carrera  Stainless Steel          Leather
# 3              Breitling          Navitimer  Stainless Steel  Stainless Steel
# 4                Cartier          Tank Solo  Stainless Steel          Leather
# ..                   ...                ...              ...              ...
# 502              Breguet          Classique    18k Rose Gold          Leather
# 503            Blancpain      Fifty Fathoms  Stainless Steel           Fabric
# 504             Longines  Master Collection  Stainless Steel          Leather
# 505  Vacheron Constantin           Overseas  Stainless Steel  Stainless Steel
# 506  Frederique Constant           Classics  Stainless Steel          Leather
#
# ...

# %%
df.isna().sum()
# Out:
# Brand                    0
# Model                    0
# Case Material            0
# Strap Material           0
# Movement Type            0
# Water Resistance         0
# Case Diameter (mm)       0
# Case Thickness (mm)      0
# Band Width (mm)          0
# Dial Color               0
# Crystal Material         0
# Complications          122
# Power Reserve           14
# Price (USD)              1
# f_stainless_steel        0
# f_gold                   0
# f_titanium               0
# dtype: int64

# %%
df['Complications']=df['Complications'].fillna("None")
df['Power Reserve']=df['Power Reserve'].fillna(df['Power Reserve'].median())
df.isna().sum()
# Out:
# Brand                  0
# Model                  0
# Case Material          0
# Strap Material         0
# Movement Type          0
# Water Resistance       0
# Case Diameter (mm)     0
# Case Thickness (mm)    0
# Band Width (mm)        0
# Dial Color             0
# Crystal Material       0
# Complications          0
# Power Reserve          0
# Price (USD)            1
# f_stainless_steel      0
# f_gold                 0
# f_titanium             0
# dtype: int64

# %%
df=df.dropna()
df.isna().sum()
# Out:
# Brand                  0
# Model                  0
# Case Material          0
# Strap Material         0
# Movement Type          0
# Water Resistance       0
# Case Diameter (mm)     0
# Case Thickness (mm)    0
# Band Width (mm)        0
# Dial Color             0
# Crystal Material       0
# Complications          0
# Power Reserve          0
# Price (USD)            0
# f_stainless_steel      0
# f_gold                 0
# f_titanium             0
# dtype: int64

# %%
df
# Out:
#                    Brand              Model    Case Material   Strap Material  \
# 0                  Rolex         Submariner  Stainless Steel  Stainless Steel
# 1                  Omega          Seamaster         Titanium           Rubber
# 2              Tag Heuer            Carrera  Stainless Steel          Leather
# 3              Breitling          Navitimer  Stainless Steel  Stainless Steel
# 4                Cartier          Tank Solo  Stainless Steel          Leather
# ..                   ...                ...              ...              ...
# 502              Breguet          Classique    18k Rose Gold          Leather
# 503            Blancpain      Fifty Fathoms  Stainless Steel           Fabric
# 504             Longines  Master Collection  Stainless Steel          Leather
# 505  Vacheron Constantin           Overseas  Stainless Steel  Stainless Steel
# 506  Frederique Constant           Classics  Stainless Steel          Leather
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df)

# %%
material_avg_prices = df.groupby('f_titanium')['Price (USD)'].agg('mean').reset_index()
material_avg_prices
# Out:
#    f_titanium   Price (USD)
# 0           0  12235.788913
# 1           1  10145.810811

# %%
df_stainless=(df[df['f_stainless_steel']==1])
df_stainless['Price (USD)'].mean()
# Out:
# 10898.35396039604

# %%
df_gold=(df[df['f_gold']==1])
df_gold['Price (USD)'].mean()
# Out:
# 22915.686274509804

# %%
df_titanium=(df[df['f_titanium']==1])
df_titanium['Price (USD)'].mean()
# Out:
# 10145.81081081081

# %%
material=['stainless','gold','titanium']
price_mean=[10898,22195,10145]

df_combined=pd.DataFrame(material,
                         price_mean)

sns.barplot(data=df_combined,x=material,y=price_mean,hue=material)
plt.title('Watch Prices by Material Type')
plt.xlabel('Price (USD)')
plt.ylabel('Frequency')
plt.show()

# %%
brand_avg_prices = df.groupby('Brand')['Price (USD)'].agg('mean').reset_index()
brand_avg_prices.sort_values(by="Price (USD)",ascending=False).head(10)
# Out:
#                   Brand   Price (USD)
# 26       Patek Philippe  38233.333333
# 2       Audemars Piguet  23734.210526
# 0      A. Lange & Sohne  23000.000000
# 6               Breguet  20696.153846
# 1      A. Lange & Söhne  20400.000000
# 37  Vacheron Constantin  19356.000000
# 27               Piaget  16383.333333
# 17               Hublot  13350.000000
# 5             Blancpain  13134.482759
# 29                Rolex  10964.814815

# %%
df['Brand'].value_counts()
# Out:
# Brand
# IWC                    39
# Audemars Piguet        38
# Patek Philippe         33
# Zenith                 30
# Blancpain              29
# Rolex                  27
# Breguet                26
# Hublot                 26
# Vacheron Constantin    25
# Panerai                25
# Omega                  23
# Girard-Perregaux       20
# Cartier                19
# Breitling              16
# Jaeger-LeCoultre       16
# Chopard                14
# Tudor                  14
# Tag Heuer              11
# Longines               10
# Ulysse Nardin          10
# Montblanc               9
# Piaget                  6
# Seiko                   5
# Jaquet Droz             5
# Hamilton                4
# Bell & Ross             3
# Sinn                    3
# Bulgari                 3
# Citizen                 2
# Oris                    2
# Tissot                  2
# TAG Heuer               2
# A. Lange & Söhne        2
# Frederique Constant     2
# Glashütte Original      1
# ...

# %%
brand_avg_prices=brand_avg_prices[brand_avg_prices['Brand']!='A. Lange & Sohne']
brand_avg_prices.sort_values(by="Price (USD)",ascending=False).head(10)
brand_avg_prices_10=brand_avg_prices.sort_values(by="Price (USD)",ascending=False).head(10)
brand_avg_prices.sort_values(by="Price (USD)",ascending=False).head(10)
# Out:
#                   Brand   Price (USD)
# 26       Patek Philippe  38233.333333
# 2       Audemars Piguet  23734.210526
# 6               Breguet  20696.153846
# 1      A. Lange & Söhne  20400.000000
# 37  Vacheron Constantin  19356.000000
# 27               Piaget  16383.333333
# 17               Hublot  13350.000000
# 5             Blancpain  13134.482759
# 29                Rolex  10964.814815
# 8               Bulgari  10933.333333

# %%
sns.barplot(data=brand_avg_prices_10,y=brand_avg_prices_10['Brand'],x=brand_avg_prices_10['Price (USD)'])
plt.title('Top 10 priciest watches brand')
plt.xlabel('Price (USD)')
plt.ylabel('Brand')
plt.show()

# %%
df100_2=df.head(100)
df100_2.to_csv("df100_2.csv")

# %%
df['Complications'].value_counts()
# Out:
# Complications
# Date                               234
# None                               121
# Chronograph                         78
# Chronograph, Date                   10
# Date, Chronograph                    9
# Chronograph, Tachymeter              7
# GMT, Date                            5
# GMT                                  4
# Date, Power Reserve Indicator        4
# Date, GMT                            4
# Date, Power Reserve                  4
# Date, Moonphase                      4
# Date, Second Time Zone               2
# Date, Moon Phase                     2
# Date, World Time                     2
# Date, Stopwatch                      2
# World Time, GMT                      1
# Date, Unidirectional Bezel           1
# Date, Chronograph, Flyback           1
# Power Reserve                        1
# Day/Date                             1
# Date, Power Reserve, Moon Phase      1
# Date, Rotating Bezel                 1
# Chronograph, Moon Phase              1
# ...

# %%
import seaborn as sns
sns.histplot(df['Price (USD)'],kde=True)
plt.title('Price Distribution')
plt.xlabel('Price (USD)')
plt.show()

# %%
df
# Out:
#                    Brand              Model    Case Material   Strap Material  \
# 0                  Rolex         Submariner  Stainless Steel  Stainless Steel
# 1                  Omega          Seamaster         Titanium           Rubber
# 2              Tag Heuer            Carrera  Stainless Steel          Leather
# 3              Breitling          Navitimer  Stainless Steel  Stainless Steel
# 4                Cartier          Tank Solo  Stainless Steel          Leather
# ..                   ...                ...              ...              ...
# 502              Breguet          Classique    18k Rose Gold          Leather
# 503            Blancpain      Fifty Fathoms  Stainless Steel           Fabric
# 504             Longines  Master Collection  Stainless Steel          Leather
# 505  Vacheron Constantin           Overseas  Stainless Steel  Stainless Steel
# 506  Frederique Constant           Classics  Stainless Steel          Leather
#
# ...

# %%
crys_mat_avg_prices = df.groupby('Crystal Material')['Price (USD)'].agg('mean').reset_index()
crys_mat_avg_prices
# Out:
#   Crystal Material   Price (USD)
# 0          Hardlex   1050.000000
# 1         Hesalite   5100.000000
# 2          Mineral    925.000000
# 3         Sapphire  12382.540984

# %%
sns.barplot(data=crys_mat_avg_prices,x=crys_mat_avg_prices['Crystal Material'],y=crys_mat_avg_prices['Price (USD)'],hue=crys_mat_avg_prices['Crystal Material'])
plt.title('Watch Prices by Material Type')
plt.xlabel('crystal material')
plt.ylabel('price (USD)')
plt.show()
